# %% [markdown]
# # Review Classification using Active Learning
#
# **Author:** [Darshan Deshpande](https://twitter.com/getdarshan)<br>
# **Date created:** 2021/10/29<br>
# **Last modified:** 2024/05/08<br>
# **Description:** Demonstrating the advantages of active learning through review classification.

# %% [markdown]
# ## Introduction
#
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity
# amongst businesses and researchers. Active Learning seeks to progressively
# train ML models so that the resultant model requires lesser amount of training data to
# achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The
# oracle is an annotator that cleans, selects, labels the data, and feeds it to the model
# when required. The oracle is a trained individual or a group of individuals that
# ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an
# initial model. The best model checkpoint is saved and then tested on a balanced test
# set. The test set must be carefully sampled because the full training process will be
# dependent on it. Once we have the initial evaluation scores, the oracle is tasked with
# labeling more samples; the number of data points to be sampled is usually determined by
# the business requirements. After that, the newly sampled data is added to the training
# set, and the training procedure repeats. This cycle continues until either an
# acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by
# demonstrating a ratio-based (least confidence) sampling strategy that results in lower
# overall false positive and negative rates when compared to a model trained on the entire
# dataset. This sampling falls under the domain of *uncertainty sampling*, in which new
# datasets are sampled based on the uncertainty that the model outputs for the
# corresponding label. In our example, we compare our model's false positive and false
# negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# 1. [Committee sampling](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Using multiple models to vote for the best data points to be sampled
# 2. [Entropy reduction](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# 3. [Minimum margin based sampling](https://arxiv.org/abs/1906.00025v1):
# Selects data points closest to the decision boundary

# %% [markdown]
# ## Importing required libraries

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"  # @param ["tensorflow", "jax", "torch"]
import keras
from keras import ops
from keras import layers
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()

# %% [markdown]
# ## Loading and preprocessing the data
#
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000
# reviews in total, including training and testing splits. We will merge these splits and
# sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
vectorizer = layers.TextVectorization(
    3000, standardize="lower_and_strip_punctuation", output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.keras", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.keras")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 150, 128)       │       384,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 150, 64)        │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 64)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - binary_accuracy: 0.6444 - false_negatives: 1629.9161 - false_positives: 5659.2516 - loss: 0.6493
# Epoch 1: val_loss improved from None to 0.58452, saving model to FullModelCheckpoint.keras
#
# Epoch 1: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 19s 56ms/step - binary_accuracy: 0.6356 - false_negatives: 5444.0000 - false_positives: 9133.0000 - loss: 0.6473 - val_binary_accuracy: 0.7094 - val_false_negatives: 1224.0000 - val_false_positives: 229.0000 - val_loss: 0.5845
# Epoch 2/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.7496 - false_negatives: 1813.1613 - false_positives: 3093.0903 - loss: 0.5394
# Epoch 2: val_loss improved from 0.58452 to 0.47572, saving model to FullModelCheckpoint.keras
#
# Epoch 2: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.7605 - false_negatives: 4126.0000 - false_positives: 5456.0000 - loss: 0.5228 - val_binary_accuracy: 0.7750 - val_false_negatives: 965.0000 - val_false_positives: 160.0000 - val_loss: 0.4757
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8137 - false_negatives: 1641.3121 - false_positives: 2112.8280 - loss: 0.4379
# Epoch 3: val_loss improved from 0.47572 to 0.37481, saving model to FullModelCheckpoint.keras
#
# Epoch 3: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8156 - false_negatives: 3506.0000 - false_positives: 3872.0000 - loss: 0.4333 - val_binary_accuracy: 0.8352 - val_false_negatives: 355.0000 - val_false_positives: 469.0000 - val_loss: 0.3748
# Epoch 4/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8474 - false_negatives: 1435.6474 - false_positives: 1686.7949 - loss: 0.3740
# Epoch 4: val_loss did not improve from 0.37481
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - binary_accuracy: 0.8417 - false_negatives: 3141.0000 - false_positives: 3193.0000 - loss: 0.3825 - val_binary_accuracy: 0.8162 - val_false_negatives: 745.0000 - val_false_positives: 174.0000 - val_loss: 0.3992
# Epoch 5/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8567 - false_negatives: 1362.2179 - false_positives: 1543.3526 - loss: 0.3544
# Epoch 5: val_loss improved from 0.37481 to 0.34411, saving model to FullModelCheckpoint.keras
#
# Epoch 5: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.8531 - false_negatives: 2957.0000 - false_positives: 2918.0000 - loss: 0.3617 - val_binary_accuracy: 0.8486 - val_false_negatives: 315.0000 - val_false_positives: 442.0000 - val_loss: 0.3441
# Epoch 6/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8710 - false_negatives: 1217.4903 - false_positives: 1429.7548 - loss: 0.3267
# Epoch 6: val_loss improved from 0.34411 to 0.33872, saving model to FullModelCheckpoint.keras
#
# Epoch 6: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8630 - false_negatives: 2707.0000 - false_positives: 2771.0000 - loss: 0.3375 - val_binary_accuracy: 0.8460 - val_false_negatives: 500.0000 - val_false_positives: 270.0000 - val_loss: 0.3387
# Epoch 7/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8745 - false_negatives: 1224.2372 - false_positives: 1326.9295 - loss: 0.3173
# Epoch 7: val_loss did not improve from 0.33872
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8708 - false_negatives: 2623.0000 - false_positives: 2547.0000 - loss: 0.3245 - val_binary_accuracy: 0.8424 - val_false_negatives: 569.0000 - val_false_positives: 219.0000 - val_loss: 0.3550
# Epoch 8/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.8777 - false_negatives: 1203.0128 - false_positives: 1291.5641 - loss: 0.3094
# Epoch 8: val_loss improved from 0.33872 to 0.33451, saving model to FullModelCheckpoint.keras
#
# Epoch 8: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - binary_accuracy: 0.8747 - false_negatives: 2527.0000 - false_positives: 2487.0000 - loss: 0.3142 - val_binary_accuracy: 0.8550 - val_false_negatives: 310.0000 - val_false_positives: 415.0000 - val_loss: 0.3345
# Epoch 9/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8864 - false_negatives: 1108.7935 - false_positives: 1215.4323 - loss: 0.2892
# Epoch 9: val_loss improved from 0.33451 to 0.32993, saving model to FullModelCheckpoint.keras
#
# Epoch 9: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8795 - false_negatives: 2409.0000 - false_positives: 2411.0000 - loss: 0.3020 - val_binary_accuracy: 0.8508 - val_false_negatives: 434.0000 - val_false_positives: 312.0000 - val_loss: 0.3299
# Epoch 10/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8930 - false_negatives: 1075.8141 - false_positives: 1116.5385 - loss: 0.2784
# Epoch 10: val_loss did not improve from 0.32993
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.8870 - false_negatives: 2298.0000 - false_positives: 2220.0000 - loss: 0.2877 - val_binary_accuracy: 0.8572 - val_false_negatives: 235.0000 - val_false_positives: 479.0000 - val_loss: 0.3323
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.8976 - false_negatives: 1022.8599 - false_positives: 1077.7834 - loss: 0.2669
# Epoch 11: val_loss improved from 0.32993 to 0.32961, saving model to FullModelCheckpoint.keras
#
# Epoch 11: finished saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - binary_accuracy: 0.8921 - false_negatives: 2189.0000 - false_positives: 2125.0000 - loss: 0.2764 - val_binary_accuracy: 0.8562 - val_false_negatives: 405.0000 - val_false_positives: 314.0000 - val_loss: 0.3296
# Epoch 12/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9019 - false_negatives: 980.8968 - false_positives: 1004.7355 - loss: 0.2563
# Epoch 12: val_loss did not improve from 0.32961
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.8967 - false_negatives: 2132.0000 - false_positives: 2000.0000 - loss: 0.2660 - val_binary_accuracy: 0.8142 - val_false_negatives: 818.0000 - val_false_positives: 111.0000 - val_loss: 0.4185
# Epoch 13/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9046 - false_negatives: 996.0828 - false_positives: 962.4713 - loss: 0.2465
# Epoch 13: val_loss did not improve from 0.32961
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.8995 - false_negatives: 2142.0000 - false_positives: 1878.0000 - loss: 0.2574 - val_binary_accuracy: 0.8576 - val_false_negatives: 286.0000 - val_false_positives: 426.0000 - val_loss: 0.3369
# Epoch 14/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.9102 - false_negatives: 946.3885 - false_positives: 926.0828 - loss: 0.2350
# Epoch 14: val_loss did not improve from 0.32961
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - binary_accuracy: 0.9048 - false_negatives: 2012.0000 - false_positives: 1796.0000 - loss: 0.2464 - val_binary_accuracy: 0.8542 - val_false_negatives: 461.0000 - val_false_positives: 268.0000 - val_loss: 0.3528
# Epoch 15/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9132 - false_negatives: 885.6474 - false_positives: 896.5577 - loss: 0.2288
# Epoch 15: val_loss did not improve from 0.32961
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.9088 - false_negatives: 1903.0000 - false_positives: 1744.0000 - loss: 0.2373 - val_binary_accuracy: 0.8516 - val_false_negatives: 495.0000 - val_false_positives: 247.0000 - val_loss: 0.3468
# Epoch 15: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8615999817848206, 'false_negatives': 402.0, 'false_positives': 290.0, 'loss': 0.32971009612083435}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.keras", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = ops.where(ops.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.keras")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 150, 128)       │       384,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 150, 64)        │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_1          │ (None, 64)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting to train with 15000 samples
# Epoch 1/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - binary_accuracy: 0.5160 - false_negatives_1: 1955.0678 - false_positives_1: 1725.7966 - loss: 0.6923
# Epoch 1: val_loss improved from None to 0.68440, saving model to AL_Model.keras
#
# Epoch 1: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - binary_accuracy: 0.5323 - false_negatives_1: 3572.0000 - false_positives_1: 3444.0000 - loss: 0.6910 - val_binary_accuracy: 0.6324 - val_false_negatives_1: 375.0000 - val_false_positives_1: 1463.0000 - val_loss: 0.6844
# Epoch 2/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.6062 - false_negatives_1: 1354.4237 - false_positives_1: 1605.9831 - loss: 0.6754
# Epoch 2: val_loss improved from 0.68440 to 0.61897, saving model to AL_Model.keras
#
# Epoch 2: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.6249 - false_negatives_1: 2520.0000 - false_positives_1: 3107.0000 - loss: 0.6637 - val_binary_accuracy: 0.6878 - val_false_negatives_1: 333.0000 - val_false_positives_1: 1228.0000 - val_loss: 0.6190
# Epoch 3/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.7013 - false_negatives_1: 963.5789 - false_positives_1: 1232.2105 - loss: 0.6007
# Epoch 3: val_loss improved from 0.61897 to 0.52053, saving model to AL_Model.keras
#
# Epoch 3: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.7095 - false_negatives_1: 1847.0000 - false_positives_1: 2510.0000 - loss: 0.5845 - val_binary_accuracy: 0.7610 - val_false_negatives_1: 424.0000 - val_false_positives_1: 771.0000 - val_loss: 0.5205
# Epoch 4/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7513 - false_negatives_1: 770.0345 - false_positives_1: 1105.3621 - loss: 0.5293
# Epoch 4: val_loss improved from 0.52053 to 0.47240, saving model to AL_Model.keras
#
# Epoch 4: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.7522 - false_negatives_1: 1532.0000 - false_positives_1: 2185.0000 - loss: 0.5264 - val_binary_accuracy: 0.7888 - val_false_negatives_1: 436.0000 - val_false_positives_1: 620.0000 - val_loss: 0.4724
# Epoch 5/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7777 - false_negatives_1: 704.9483 - false_positives_1: 969.9138 - loss: 0.4952
# Epoch 5: val_loss improved from 0.47240 to 0.43367, saving model to AL_Model.keras
#
# Epoch 5: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.7799 - false_negatives_1: 1362.0000 - false_positives_1: 1939.0000 - loss: 0.4867 - val_binary_accuracy: 0.8086 - val_false_negatives_1: 475.0000 - val_false_positives_1: 482.0000 - val_loss: 0.4337
# Epoch 6/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8021 - false_negatives_1: 640.2241 - false_positives_1: 868.0345 - loss: 0.4518
# Epoch 6: val_loss improved from 0.43367 to 0.41778, saving model to AL_Model.keras
#
# Epoch 6: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.7985 - false_negatives_1: 1280.0000 - false_positives_1: 1743.0000 - loss: 0.4519 - val_binary_accuracy: 0.8212 - val_false_negatives_1: 437.0000 - val_false_positives_1: 457.0000 - val_loss: 0.4178
# Epoch 7/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - binary_accuracy: 0.8213 - false_negatives_1: 579.8070 - false_positives_1: 765.5088 - loss: 0.4218
# Epoch 7: val_loss improved from 0.41778 to 0.40728, saving model to AL_Model.keras
#
# Epoch 7: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - binary_accuracy: 0.8187 - false_negatives_1: 1160.0000 - false_positives_1: 1560.0000 - loss: 0.4229 - val_binary_accuracy: 0.8142 - val_false_negatives_1: 234.0000 - val_false_positives_1: 695.0000 - val_loss: 0.4073
# Epoch 8/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8401 - false_negatives_1: 537.1207 - false_positives_1: 697.5172 - loss: 0.3889
# Epoch 8: val_loss did not improve from 0.40728
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8357 - false_negatives_1: 1085.0000 - false_positives_1: 1380.0000 - loss: 0.3960 - val_binary_accuracy: 0.8078 - val_false_negatives_1: 180.0000 - val_false_positives_1: 781.0000 - val_loss: 0.4194
# Epoch 9/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8387 - false_negatives_1: 527.2414 - false_positives_1: 680.3966 - loss: 0.3877
# Epoch 9: val_loss did not improve from 0.40728
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8439 - false_negatives_1: 1025.0000 - false_positives_1: 1317.0000 - loss: 0.3830 - val_binary_accuracy: 0.7810 - val_false_negatives_1: 121.0000 - val_false_positives_1: 974.0000 - val_loss: 0.4675
# Epoch 10/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8480 - false_negatives_1: 485.4386 - false_positives_1: 621.0702 - loss: 0.3661
# Epoch 10: val_loss improved from 0.40728 to 0.37378, saving model to AL_Model.keras
#
# Epoch 10: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.8521 - false_negatives_1: 978.0000 - false_positives_1: 1240.0000 - loss: 0.3622 - val_binary_accuracy: 0.8392 - val_false_negatives_1: 326.0000 - val_false_positives_1: 478.0000 - val_loss: 0.3738
# Epoch 11/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8725 - false_negatives_1: 442.2759 - false_positives_1: 537.9310 - loss: 0.3283
# Epoch 11: val_loss did not improve from 0.37378
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8665 - false_negatives_1: 910.0000 - false_positives_1: 1092.0000 - loss: 0.3378 - val_binary_accuracy: 0.7940 - val_false_negatives_1: 124.0000 - val_false_positives_1: 906.0000 - val_loss: 0.4561
# Epoch 12/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8754 - false_negatives_1: 412.2931 - false_positives_1: 531.5345 - loss: 0.3288
# Epoch 12: val_loss did not improve from 0.37378
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8731 - false_negatives_1: 846.0000 - false_positives_1: 1058.0000 - loss: 0.3237 - val_binary_accuracy: 0.8240 - val_false_negatives_1: 647.0000 - val_false_positives_1: 233.0000 - val_loss: 0.4095
# Epoch 13/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - binary_accuracy: 0.8799 - false_negatives_1: 431.6034 - false_positives_1: 504.1207 - loss: 0.3125
# Epoch 13: val_loss did not improve from 0.37378
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - binary_accuracy: 0.8739 - false_negatives_1: 864.0000 - false_positives_1: 1027.0000 - loss: 0.3204 - val_binary_accuracy: 0.8258 - val_false_negatives_1: 637.0000 - val_false_positives_1: 234.0000 - val_loss: 0.3973
# Epoch 14/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8848 - false_negatives_1: 405.8246 - false_positives_1: 452.9298 - loss: 0.3053
# Epoch 14: val_loss improved from 0.37378 to 0.37118, saving model to AL_Model.keras
#
# Epoch 14: finished saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8855 - false_negatives_1: 807.0000 - false_positives_1: 910.0000 - loss: 0.3038 - val_binary_accuracy: 0.8478 - val_false_negatives_1: 278.0000 - val_false_positives_1: 483.0000 - val_loss: 0.3712
# Epoch 15/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8896 - false_negatives_1: 379.4655 - false_positives_1: 459.6897 - loss: 0.2901
# Epoch 15: val_loss did not improve from 0.37118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8912 - false_negatives_1: 746.0000 - false_positives_1: 886.0000 - loss: 0.2875 - val_binary_accuracy: 0.8464 - val_false_negatives_1: 431.0000 - val_false_positives_1: 337.0000 - val_loss: 0.3729
# Epoch 16/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9010 - false_negatives_1: 352.5000 - false_positives_1: 414.4655 - loss: 0.2762
# Epoch 16: val_loss did not improve from 0.37118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8975 - false_negatives_1: 713.0000 - false_positives_1: 824.0000 - loss: 0.2768 - val_binary_accuracy: 0.8410 - val_false_negatives_1: 451.0000 - val_false_positives_1: 344.0000 - val_loss: 0.3768
# Epoch 17/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9092 - false_negatives_1: 315.9123 - false_positives_1: 352.1404 - loss: 0.2613
# Epoch 17: val_loss did not improve from 0.37118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.9073 - false_negatives_1: 660.0000 - false_positives_1: 730.0000 - loss: 0.2566 - val_binary_accuracy: 0.8246 - val_false_negatives_1: 215.0000 - val_false_positives_1: 662.0000 - val_loss: 0.4173
# Epoch 18/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9166 - false_negatives_1: 290.0526 - false_positives_1: 352.2632 - loss: 0.2383
# Epoch 18: val_loss did not improve from 0.37118
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.9089 - false_negatives_1: 627.0000 - false_positives_1: 740.0000 - loss: 0.2489 - val_binary_accuracy: 0.8386 - val_false_negatives_1: 338.0000 - val_false_positives_1: 469.0000 - val_loss: 0.3886
# Epoch 18: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 361.0, Number of ones incorrectly classified: 446.0
# Sample ratio for positives: 0.5526641883519207, Sample ratio for negatives:0.4473358116480793
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8816 - false_negatives_2: 517.6203 - false_positives_2: 624.0253 - loss: 0.3202
# Epoch 1: val_loss did not improve from 0.37118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - binary_accuracy: 0.8934 - false_negatives_2: 962.0000 - false_positives_2: 1169.0000 - loss: 0.2921 - val_binary_accuracy: 0.8412 - val_false_negatives_2: 299.0000 - val_false_positives_2: 495.0000 - val_loss: 0.3874
# Epoch 2/20
# 77/79 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9126 - false_negatives_2: 418.0130 - false_positives_2: 464.9091 - loss: 0.2542
# Epoch 2: val_loss did not improve from 0.37118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.9088 - false_negatives_2: 862.0000 - false_positives_2: 962.0000 - loss: 0.2583 - val_binary_accuracy: 0.8406 - val_false_negatives_2: 296.0000 - val_false_positives_2: 501.0000 - val_loss: 0.3827
# Epoch 3/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9172 - false_negatives_2: 402.1923 - false_positives_2: 460.6923 - loss: 0.2391
# Epoch 3: val_loss did not improve from 0.37118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.9141 - false_negatives_2: 800.0000 - false_positives_2: 917.0000 - loss: 0.2440 - val_binary_accuracy: 0.8364 - val_false_negatives_2: 256.0000 - val_false_positives_2: 562.0000 - val_loss: 0.4084
# Epoch 4/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.9225 - false_negatives_2: 352.8590 - false_positives_2: 420.8333 - loss: 0.2247
# Epoch 4: val_loss did not improve from 0.37118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - binary_accuracy: 0.9247 - false_negatives_2: 695.0000 - false_positives_2: 811.0000 - loss: 0.2239 - val_binary_accuracy: 0.8448 - val_false_negatives_2: 399.0000 - val_false_positives_2: 377.0000 - val_loss: 0.4071
# Epoch 5/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.9330 - false_negatives_2: 326.5190 - false_positives_2: 367.2278 - loss: 0.2069
# Epoch 5: val_loss did not improve from 0.37118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - binary_accuracy: 0.9305 - false_negatives_2: 658.0000 - false_positives_2: 731.0000 - loss: 0.2131 - val_binary_accuracy: 0.8466 - val_false_negatives_2: 330.0000 - val_false_positives_2: 437.0000 - val_loss: 0.4139
# Epoch 6/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9413 - false_negatives_2: 291.4304 - false_positives_2: 321.7342 - loss: 0.1885
# Epoch 6: val_loss did not improve from 0.37118
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.9388 - false_negatives_2: 570.0000 - false_positives_2: 653.0000 - loss: 0.1914 - val_binary_accuracy: 0.8398 - val_false_negatives_2: 427.0000 - val_false_positives_2: 374.0000 - val_loss: 0.4321
# Epoch 6: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 313.0, Number of ones incorrectly classified: 480.0
# Sample ratio for positives: 0.605296343001261, Sample ratio for negatives:0.39470365699873894
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - binary_accuracy: 0.8554 - false_negatives_3: 784.7755 - false_positives_3: 960.1939 - loss: 0.3611
# Epoch 1: val_loss did not improve from 0.37118
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - binary_accuracy: 0.8667 - false_negatives_3: 1515.0000 - false_positives_3: 1816.0000 - loss: 0.3395 - val_binary_accuracy: 0.8324 - val_false_negatives_3: 197.0000 - val_false_positives_3: 641.0000 - val_loss: 0.3899
# Epoch 2/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8853 - false_negatives_3: 687.0000 - false_positives_3: 784.2990 - loss: 0.3036
# Epoch 2: val_loss improved from 0.37118 to 0.34805, saving model to AL_Model.keras
#
# Epoch 2: finished saving model to AL_Model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.8800 - false_negatives_3: 1385.0000 - false_positives_3: 1616.0000 - loss: 0.3144 - val_binary_accuracy: 0.8538 - val_false_negatives_3: 360.0000 - val_false_positives_3: 371.0000 - val_loss: 0.3480
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8949 - false_negatives_3: 648.2755 - false_positives_3: 725.3980 - loss: 0.2895
# Epoch 3: val_loss did not improve from 0.34805
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - binary_accuracy: 0.8918 - false_negatives_3: 1263.0000 - false_positives_3: 1443.0000 - loss: 0.2944 - val_binary_accuracy: 0.8478 - val_false_negatives_3: 448.0000 - val_false_positives_3: 313.0000 - val_loss: 0.3564
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8976 - false_negatives_3: 611.3163 - false_positives_3: 677.4388 - loss: 0.2818
# Epoch 4: val_loss did not improve from 0.34805
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - binary_accuracy: 0.8971 - false_negatives_3: 1204.0000 - false_positives_3: 1368.0000 - loss: 0.2819 - val_binary_accuracy: 0.8548 - val_false_negatives_3: 326.0000 - val_false_positives_3: 400.0000 - val_loss: 0.3551
# Epoch 5/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - binary_accuracy: 0.9076 - false_negatives_3: 546.3711 - false_positives_3: 641.1753 - loss: 0.2608
# Epoch 5: val_loss did not improve from 0.34805
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - binary_accuracy: 0.9042 - false_negatives_3: 1107.0000 - false_positives_3: 1289.0000 - loss: 0.2669 - val_binary_accuracy: 0.8342 - val_false_negatives_3: 191.0000 - val_false_positives_3: 638.0000 - val_loss: 0.4397
# Epoch 6/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9071 - false_negatives_3: 525.7423 - false_positives_3: 622.6186 - loss: 0.2545
# Epoch 6: val_loss did not improve from 0.34805
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.9094 - false_negatives_3: 1045.0000 - false_positives_3: 1220.0000 - loss: 0.2514 - val_binary_accuracy: 0.8214 - val_false_negatives_3: 682.0000 - val_false_positives_3: 211.0000 - val_loss: 0.4283
# Epoch 6: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 399.0, Number of ones incorrectly classified: 361.0
# Sample ratio for positives: 0.475, Sample ratio for negatives:0.525
# Starting training with 29998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - binary_accuracy: 0.8729 - false_negatives_4: 870.0000 - false_positives_4: 1011.0593 - loss: 0.3366
# Epoch 1: val_loss did not improve from 0.34805
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - binary_accuracy: 0.8767 - false_negatives_4: 1694.0000 - false_positives_4: 2004.0000 - loss: 0.3219 - val_binary_accuracy: 0.8070 - val_false_negatives_4: 827.0000 - val_false_positives_4: 138.0000 - val_loss: 0.4262
# Epoch 2/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8955 - false_negatives_4: 751.2564 - false_positives_4: 844.8632 - loss: 0.2841
# Epoch 2: val_loss did not improve from 0.34805
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - binary_accuracy: 0.8910 - false_negatives_4: 1532.0000 - false_positives_4: 1738.0000 - loss: 0.2912 - val_binary_accuracy: 0.8274 - val_false_negatives_4: 687.0000 - val_false_positives_4: 176.0000 - val_loss: 0.3844
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - binary_accuracy: 0.9018 - false_negatives_4: 707.5085 - false_positives_4: 798.7881 - loss: 0.2683
# Epoch 3: val_loss improved from 0.34805 to 0.34328, saving model to AL_Model.keras
#
# Epoch 3: finished saving model to AL_Model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - binary_accuracy: 0.8967 - false_negatives_4: 1428.0000 - false_positives_4: 1672.0000 - loss: 0.2774 - val_binary_accuracy: 0.8516 - val_false_negatives_4: 346.0000 - val_false_positives_4: 396.0000 - val_loss: 0.3433
# Epoch 4/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9080 - false_negatives_4: 661.7265 - false_positives_4: 757.6667 - loss: 0.2570
# Epoch 4: val_loss did not improve from 0.34328
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.9048 - false_negatives_4: 1326.0000 - false_positives_4: 1531.0000 - loss: 0.2637 - val_binary_accuracy: 0.8526 - val_false_negatives_4: 269.0000 - val_false_positives_4: 468.0000 - val_loss: 0.3516
# Epoch 5/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9120 - false_negatives_4: 631.8220 - false_positives_4: 719.9746 - loss: 0.2453
# Epoch 5: val_loss did not improve from 0.34328
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - binary_accuracy: 0.9117 - false_negatives_4: 1246.0000 - false_positives_4: 1404.0000 - loss: 0.2484 - val_binary_accuracy: 0.8198 - val_false_negatives_4: 142.0000 - val_false_positives_4: 759.0000 - val_loss: 0.4811
# Epoch 6/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.9194 - false_negatives_4: 557.7458 - false_positives_4: 667.7373 - loss: 0.2284
# Epoch 6: val_loss did not improve from 0.34328
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - binary_accuracy: 0.9160 - false_negatives_4: 1161.0000 - false_positives_4: 1359.0000 - loss: 0.2355 - val_binary_accuracy: 0.8330 - val_false_negatives_4: 149.0000 - val_false_positives_4: 686.0000 - val_loss: 0.4595
# Epoch 7/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.9264 - false_negatives_4: 518.3333 - false_positives_4: 597.0427 - loss: 0.2070
# Epoch 7: val_loss did not improve from 0.34328
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.9244 - false_negatives_4: 1061.0000 - false_positives_4: 1206.0000 - loss: 0.2164 - val_binary_accuracy: 0.8434 - val_false_negatives_4: 486.0000 - val_false_positives_4: 297.0000 - val_loss: 0.3898
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8500000238418579, 'false_negatives_4': 369.0, 'false_positives_4': 381.0, 'loss': 0.3506360650062561}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency
# benefits of using Active Learning, as it eliminates the need to annotate large amounts of
# data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full dataset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
#
# For further reading about the types of sampling ratios, training techniques or available
# open source libraries/implementations, you can refer to the resources below:
#
# 1. [Active Learning Literature Survey](http://burrsettles.com/pub/settles.activelearning.pdf) (Burr Settles, 2010).
# 2. [modAL](https://github.com/modAL-python/modAL): A Modular Active Learning framework.
# 3. Google's unofficial [Active Learning playground](https://github.com/google/active-learning).

# %% [markdown]
# ## Relevant Chapters from Deep Learning with Python
# - [Chapter 14: Text classification](https://deeplearningwithpython.io/chapters/chapter14_text-classification)
